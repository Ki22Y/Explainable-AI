# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# 1. Load the Dataset (CIFAR-10)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize for 3 channels (RGB)
])

# Load CIFAR-10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# 2. Define a Simple CNN Model for CIFAR-10
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)  # Input channels = 3 (RGB)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 8 * 8, 128)  # Adjusted for CIFAR-10's 32x32 input size
        self.fc2 = nn.Linear(128, 10)  # 10 classes for CIFAR-10

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)  # Output size: 16x16
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)  # Output size: 8x8
        x = x.view(-1, 32 * 8 * 8)  # Flatten the tensor
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize the Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 3. Train the CNN Model
def train(model, trainloader, criterion, optimizer, epochs=3):
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)  # CNN outputs (logits)

            # Print CNN output (logits) for the first image in the batch
            print(f"Logits for first image in batch: {outputs[0]}")  # First image in the batch

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(trainloader):.4f}")

train(model, trainloader, criterion, optimizer)

# 4. Extract Features for Surrogate Model
def extract_features(model, dataloader):
    model.eval()
    features, labels = [], []
    with torch.no_grad():
        for images, lbls in dataloader:
            images = images.to(device)
            outputs = model(images)  # CNN outputs (logits)

            # Print CNN outputs (logits) for the first image in each batch
            print(f"Logits for first image in batch: {outputs[0]}")  # This will print the logits for the first image

            features.extend(outputs.cpu().numpy())  # Extract CNN outputs as features
            labels.extend(lbls.numpy())
    return np.array(features), np.array(labels)

X_train, y_train = extract_features(model, trainloader)
X_test, y_test = extract_features(model, testloader)

# 5. Train a Decision Tree Surrogate Model
dt = DecisionTreeClassifier(max_depth=5)  # Decision Tree model
dt.fit(X_train, y_train)

# Evaluate Surrogate Model
acc = dt.score(X_test, y_test)
print(f"Surrogate Model Accuracy: {acc * 100:.2f}%")

# 6. Visualize the Decision Tree (Surrogate Model)
def visualize_surrogate_model(dt):
    plt.figure(figsize=(12, 8))
    plot_tree(dt, filled=True, feature_names=[f"Feature {i}" for i in range(X_train.shape[1])], class_names=[str(i) for i in range(10)], rounded=True)
    plt.title("Surrogate Model - Decision Tree")
    plt.show()

visualize_surrogate_model(dt)

# 7. Visualize Feature Importance of the Surrogate Model
def plot_feature_importance(dt, feature_names):
    feature_importances = dt.feature_importances_
    indices = np.argsort(feature_importances)[::-1]

    plt.figure(figsize=(10, 6))
    plt.title("Feature Importances (Surrogate Model)")
    plt.barh(range(X_train.shape[1]), feature_importances[indices], align="center")
    plt.yticks(range(X_train.shape[1]), [f"Feature {i}" for i in indices])
    plt.xlabel("Importance")
    plt.show()

# Visualizing Feature Importance of the Surrogate Model
plot_feature_importance(dt, [f"Feature {i}" for i in range(X_train.shape[1])])

# --- Visualizing Feature Maps from the CNN --- #
def visualize_feature_maps(model, input_image):
    model.eval()
    layers = [model.conv1, model.conv2]  # Choose the convolutional layers to visualize
    activations = []

    def save_activation(name):
        def hook(model, input, output):
            activations.append(output)
        return hook

    # Register hooks to the convolutional layers
    hooks = []
    for layer in layers:
        hooks.append(layer.register_forward_hook(save_activation(layer.__class__.__name__)))

    # Perform a forward pass
    input_image = input_image.unsqueeze(0).to(device)
    model(input_image)

    # Visualize the feature maps
    for i, activation in enumerate(activations):
        activation = activation.squeeze(0).cpu().detach().numpy()
        num_filters = activation.shape[0]

        # Display the feature maps for each filter
        fig, axes = plt.subplots(1, num_filters, figsize=(15, 8))
        for j in range(num_filters):
            axes[j].imshow(activation[j], cmap='gray')
            axes[j].axis('off')
            axes[j].set_title(f"Filter {j + 1}")
        plt.show()

    # Remove hooks after visualization
    for hook in hooks:
        hook.remove()

# Visualize feature maps of the first image in the test set
sample_image, sample_label = testset[0]
visualize_feature_maps(model, sample_image)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:02<00:00, 77.9MB/s]
# Streaming output truncated to the last 5000 lines.
#          3.7949, -1.3403], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-1.7560, -1.7337, -0.4900,  1.8603, -2.2087,  2.8997, -3.1858, -0.0293,
#          0.3902, -0.8574], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-1.6575, -1.7503, -0.2740,  1.6616, -1.2981,  1.6437,  0.4851,  0.6655,
#         -3.6011, -0.1845], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-2.3234, -2.4069,  0.0545,  0.5359,  0.0110, -0.2901,  2.3526, -0.8831,
#         -1.6374, -1.4953], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-0.6513,  1.3865, -1.1227, -1.9419, -1.6049, -1.8891,  0.2529,  2.1954,
#         -2.2886,  2.4238], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([ 0.2487,  1.3808,  0.0210, -1.1160,  1.1608, -1.8147, -0.4736,  0.2344,
#         -1.0862,  1.0384], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-2.8740, -2.8935,  1.1267,  1.3609, -1.1358,  1.3769,  0.7612, -1.0724,
#         -2.4771, -0.1637], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([ 2.9460,  6.0737, -0.8693, -4.5435,  0.2253, -5.3527, -1.1294, -2.0173,
#          2.8968,  1.8462], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-0.9656, -4.7998,  3.4395,  0.5072,  2.2139, -0.1305,  0.9214,  0.7783,
#         -4.6494, -2.9083], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-1.2853, -1.2541,  0.3764,  0.3150, -1.1973, -1.5379,  0.7404, -2.4286,
#         -0.6845,  0.4832], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor
grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-3.0308, -3.3363, -0.9656,  1.1748,  1.1084,  0.0662,  3.9396, -1.4063,
#         -3.0428, -2.0941], grad_fn=<SelectBackward0>)
# Logits for first image in batch: tensor([-1.7247, -1.6116,  1.0768,  1.9439,  0.2235,  3.1207, -0.2829,  0.0858,
#         -3.7838, -1.0280], grad_fn=<SelectBackward0>)
# ...
#         -1.6549, -2.5631])
# Logits for first image in batch: tensor([-1.0182,  1.1973, -2.5227,  0.3603,  2.3140, -0.1478, -5.9449,  2.8101,
#         -0.5664, -0.7892])
# Logits for first image in batch: tensor([-1.3200, -3.8848,  2.2897, -0.7029,  4.2023, -1.3522,  0.6596,  0.0265,
#         -4.3667, -4.1470])
# Logits for first image in batch: tensor([-0.1713,  1.9556, -0.7808, -0.6949, -2.9320, -2.6512, -0.8290, -1.5584,
#         -0.3180,  4.2723])
# Logits for first image in batch: tensor([ 1.0071,  1.7897, -3.3502, -1.5844, -2.9441, -3.3184, -2.9791, -3.8911,
#          4.9996,  4.0199])
# Logits for first image in batch: tensor([ 0.4420,  4.1321, -1.5910, -0.6473, -5.2984, -2.8047,  0.7986, -4.5705,
#          3.0480,  0.6049])
# Logits for first image in batch: tensor([-1.8416, -2.6913, -0.3437,  0.2261,  3.2716,  0.2325, -1.9995,  2.0764,
#         -1.4968, -3.4933])
# Logits for first image in batch: tensor([-0.3525, -2.9418,  1.4495, -0.9042, -0.8816,  1.2522, -0.7738,  2.2707,
#         -3.8060, -1.0006])
# Logits for first image in batch: tensor([ 1.8931,  0.1537, -0.9600, -2.2945, -1.2573, -3.7417, -0.7487, -0.8836,
#          1.0433,  1.3921])
# Logits for first image in batch: tensor([ 1.7929, -0.8335,  2.8384, -1.4686,  1.0886, -1.9941,  0.8573, -0.4471,
#         -3.6297, -2.2670])
# Logits for first image in batch: tensor([ 2.5371,  1.2972, -2.3876, -2.3195, -2.0739, -4.5285, -2.2562, -4.2678,
#          4.4733,  1.7996])
# Logits for first image in batch: tensor([-4.5506, -6.8647, -0.3013,  1.9028,  0.0169,  1.8155,  1.4948, -1.0853,
#         -1.9194, -3.7840])
# Logits for first image in batch: tensor([ 0.3596,  6.9039, -1.9249, -1.1107, -3.1275, -1.8067, -2.1638, -3.1132,
#          0.1147,  4.2924])
# Logits for first image in batch: tensor([-2.9769, -4.8757, -1.0827,  3.3883, -0.3342,  3.8425, -4.5567,  2.2693,
#         -0.6356, -4.2195])
# Logits for first image in batch: tensor([-2.7887, -3.4478, -0.1105, -0.1803,  1.7381,  0.5252,  0.6021,  3.7699,
#         -5.0157, -3.4854])
# Logits for first image in batch: tensor([ 0.3598, -4.0899,  0.4258,  0.3462,  0.8694, -0.7611, -1.2856, -1.6634,
#          0.6453, -3.6407])
# Logits for first image in batch: tensor([ 0.4517, -0.5578, -0.3458, -0.1532, -0.7441, -1.8125, -3.4668,  0.0903,
#          0.5322,  1.7952])
# Logits for first image in batch: tensor([-4.3927e+00, -3.0938e+00,  4.0821e-03,  2.0323e+00, -7.2398e-02,
#          1.1864e-01,  2.7747e+00, -3.3345e+00, -4.1197e-01, -3.3653e+00])
# Logits for first image in batch: tensor([ 1.4421,  5.8261, -1.2835, -0.9769, -3.5295, -2.7797, -2.8300, -3.3987,
#         -1.1010,  5.6640])
# Logits for first image in batch: tensor([ 1.9543, -1.8600,  1.7142, -0.3549,  0.2853, -1.7318, -0.8178, -4.3527,
#          1.7987, -2.0955])
# Logits for first image in batch: tensor([-4.3959, -3.5980, -0.8367,  3.8299, -2.5141,  3.2959,  1.5542,  0.2638,
#         -6.8657, -1.7964])
# Logits for first image in batch: tensor([ 2.6798, -0.5648,  0.7721, -0.7197, -0.2089, -2.6054, -2.5322, -3.8434,
#          3.7141, -1.4277])
# Logits for first image in batch: tensor([-2.3089, -7.2430,  2.7960,  1.4024,  1.4134,  3.5866, -0.2506,  1.6295,
#         -6.4463, -6.3750])
# Logits for first image in batch: tensor([-0.2414, -3.9892,  0.0660,  0.0843,  1.0552,  2.4477, -2.3587,  1.1988,
#         -2.6812, -2.2354])
# Logits for first image in batch: tensor([ 2.3923,  7.9309, -2.9679, -4.2081, -3.3829, -6.2263, -3.6530, -2.8819,
#          2.8241,  5.1771])
# Logits for first image in batch: tensor([-4.0953, -3.1617, -0.9556,  2.3126,  0.8379,  2.2150,  1.7050, -1.9626,
#         -3.1971, -3.0085])
# Logits for first image in batch: tensor([ 0.0778, -4.2205,  2.8882,  0.0043,  1.4144, -1.6544,  2.7145, -2.7965,
#         -2.5531, -2.3755])
# Logits for first image in batch: tensor([-1.7162,  1.1206, -1.7588, -1.0850, -2.4815, -1.0509,  0.9778, -0.5027,
#         -2.9988,  4.8154])
# Logits for first image in batch: tensor([-0.2080, -7.2616, -0.8574,  0.4377,  2.7262,  2.0285, -2.7929,  5.7758,
#         -6.8235, -2.2059])
# Logits for first image in batch: tensor([-0.7889, -2.5259, -1.4665,  0.9161,  1.5385, -1.0189,  3.1865, -0.7250,
#         -5.1669, -1.4670])
# Logits for first image in batch: tensor([-2.5056, -7.0708,  0.6455, -1.1554,  1.1313,  0.2344,  6.3754, -1.9567,
#         -6.7987, -4.4117])
# Logits for first image in batch: tensor([ 2.1798,  5.1848, -0.8836, -0.1003, -2.1912, -2.9056, -1.4983, -6.5931,
#          1.5435,  1.1796])
# Logits for first image in batch: tensor([ 0.9434,  1.9108, -1.8975, -1.7085, -2.0106, -1.4625, -4.7032,  1.5942,
#         -2.3467,  7.2714])
# Logits for first image in batch: tensor([-1.3359, -2.3477, -1.0789,  2.7927,  1.5116,  1.6222, -1.1864, -0.0592,
#         -2.8659, -3.5537])
# Logits for first image in batch: tensor([ 1.8138,  3.1387, -2.0288, -1.5774, -1.3394, -2.5217, -2.5973, -1.4454,
#          0.2153,  5.8519])
# Logits for first image in batch: tensor([ 2.1120,  8.4865, -4.0359, -2.6350, -1.4607, -5.6590, -2.8398, -7.9365,
#          4.0523,  3.9665])
# Logits for first image in batch: tensor([-1.0952,  3.2134, -1.7634,  0.6955, -4.8639,  0.1168, -0.8237, -2.9523,
#         -1.4205,  4.9388])
# Logits for first image in batch: tensor([ 0.5014, -0.1314, -2.3737, -0.2112, -1.5902, -1.7364, -4.7494, -1.1016,
#          2.5091,  3.2183])
# Logits for first image in batch: tensor([-2.5605, -3.2671, -0.4965,  0.3061,  0.2363,  0.4964,  0.8364,  0.6106,
#         -3.0732,  0.0768])
# Logits for first image in batch: tensor([ 0.4831,  0.1269, -0.6132, -1.2867, -2.0676, -1.4901, -2.2999,  0.7979,
#         -2.6399,  5.4448])
# Logits for first image in batch: tensor([-1.7730, -3.7525, -0.2586,  1.9213, -4.4800,  5.0561, -0.8395, -0.4305,
#         -1.6046, -1.8324])
# Logits for first image in batch: tensor([-1.4953, -6.8703, -1.9467,  4.0287, -0.9609,  4.6539, -5.1136,  1.0739,
#          2.1419, -5.6099])
# Logits for first image in batch: tensor([ 2.4914,  1.1910, -2.4547, -2.1452, -1.1831, -3.5298, -1.0926, -1.8176,
#          0.1170,  5.5539])
# Logits for first image in batch: tensor([-1.4855, -3.9544,  1.1286,  0.1881,  1.0380,  1.1717,  0.7720,  0.1948,
#         -3.1149, -2.5110])
# Logits for first image in batch: tensor([-0.8023, -3.6273,  0.9408, -1.9176,  0.9046, -0.5398, -2.2322,  5.9975,
#         -4.5133, -1.5504])
# Logits for first image in batch: tensor([-0.8781,  0.6816, -1.2910,  0.7897, -2.3763,  0.4196, -2.5670,  0.2436,
#         -2.8945,  2.1983])
# Logits for first image in batch: tensor([ 0.0685, -5.8557, -0.6017,  0.3105,  1.7174,  0.9676, -3.7039,  7.0681,
#         -9.0650, -2.4693])
# Logits for first image in batch: tensor([ 1.3743, -5.6841,  3.8803, -1.0119,  1.4011, -2.3294,  0.3494, -1.1000,
#         -1.5888, -4.4611])
# Logits for first image in batch: tensor([-0.6204, -3.3808, -0.1853, -1.5690, -0.5162, -1.1309, -1.6357,  3.4434,
#         -3.2527,  1.5081])
# Logits for first image in batch: tensor([-1.1845, -5.8046, -0.9595,  2.7659,  1.9465,  2.9951, -4.2283,  0.7621,
#         -4.9391, -2.1389])
# Logits for first image in batch: tensor([-1.4628,  0.8202, -1.5651, -3.6268, -0.0685, -1.3911, -3.1774,  4.1692,
#         -4.5758,  4.4414])
# Logits for first image in batch: tensor([-2.3930, -3.8747, -0.0118, -0.1649,  0.3761, -0.7089,  3.6861, -2.4821,
#         -3.2021, -1.4241])
# Logits for first image in batch: tensor([ 0.1328,  7.4814, -1.5840, -2.1047, -2.7677, -2.5334, -1.0832, -3.1874,
#         -0.1335,  5.3151])
# Logits for first image in batch: tensor([-3.8575, -8.0041,  1.1551,  1.2308,  0.6301,  3.7133, -1.9483,  4.5242,
#         -5.5175, -4.2808])
# Logits for first image in batch: tensor([ 0.5751,  1.2169, -1.0008, -2.7338, -2.3991, -3.6260, -2.3290, -4.4449,
#          5.8895,  1.5817])
# Logits for first image in batch: tensor([-2.9057, -6.0520,  0.6530,  2.0327, -0.3023,  2.0623,  2.3312, -2.8039,
#         -0.6693, -4.9002])
# Logits for first image in batch: tensor([ 2.8464,  0.4470,  2.4969, -2.1065,  3.1039, -2.5815, -2.9663, -0.6848,
#         -2.9089,  0.8740])
# Logits for first image in batch: tensor([ 3.1050,  2.1774, -0.5340, -2.0056, -0.9841, -5.1115, -6.9705, -2.5267,
#          4.5031, -0.9026])
# Logits for first image in batch: tensor([-1.9927,  2.2183, -1.2948,  0.9448, -1.2481, -1.4245,  2.2711, -3.5681,
#         -1.8768,  1.4135])
# Logits for first image in batch: tensor([-0.3064, -4.3667, -0.9374, -0.0288,  0.2462,  0.4293, -3.3514,  2.7868,
#         -1.7385,  0.7606])
# Logits for first image in batch: tensor([-2.4004, -6.3378,  1.3396,  1.0128, -2.1212,  5.2704, -0.9807, -0.2020,
#         -1.7994, -2.3974])
# Logits for first image in batch: tensor([-1.6856, -2.4405, -0.7837,  2.5563,  1.3389,  3.1837, -1.2430,  1.0411,
#         -3.6334, -3.0780])
# Logits for first image in batch: tensor([ 0.2599, -5.7263,  4.0038, -0.1314,  2.9186,  0.8038, -0.2154, -0.8391,
#         -4.8581, -3.8523])
# Logits for first image in batch: tensor([ 0.6659,  2.5489, -2.9753, -1.4601, -2.6005, -2.4082, -4.7630, -1.9614,
#          2.3055,  4.8644])
# Logits for first image in batch: tensor([ 1.1024,  0.4081, -1.5768, -1.9503, -2.1675, -3.4511, -2.5877, -2.8368,
#          4.0812,  1.7249])
# Logits for first image in batch: tensor([ 1.5825, -4.5920, -1.2380,  0.7271,  0.8921, -0.5211, -0.6135,  1.2209,
#         -5.5054,  0.9657])
# Logits for first image in batch: tensor([ 0.7526, -2.4038, -0.0873,  0.5923,  1.6627, -0.3464,  1.1562, -2.4002,
#         -2.4412, -2.2926])
# Logits for first image in batch: tensor([ 0.9612, -0.0968, -1.1912,  1.0660, -0.5761,  0.3486, -2.6769, -0.8113,
#          0.1485,  0.7505])
# Logits for first image in batch: tensor([-2.6009,  0.6750, -0.3236, -0.8457, -1.7382,  0.3473,  1.7549, -1.6214,
#          0.3506, -1.1803])
# Logits for first image in batch: tensor([-0.9461, -2.4187,  1.1925,  2.9878, -1.0594,  2.5510, -2.8972, -0.7149,
#         -2.6264, -2.3270])
# Logits for first image in batch: tensor([-3.2382,  3.7556, -3.7852, -0.7476, -3.2882, -0.5357,  0.9057, -3.6514,
#          0.7989,  4.2633])
# Logits for first image in batch: tensor([ 1.2034, -0.1010, -1.0602, -1.2535, -1.7104, -3.3557, -2.8694, -3.4549,
#          4.7374,  0.1265])
# Logits for first image in batch: tensor([-3.1698, -3.6560,  0.4565,  0.2436, -0.0259,  2.0339, -0.9571,  3.4244,
#         -3.5364, -1.4396])
# Logits for first image in batch: tensor([ 0.1561,  5.2845, -2.1691, -2.7227, -2.0131, -2.1246, -1.7327, -0.2426,
#         -1.2855,  5.1341])
# Logits for first image in batch: tensor([ 1.4221, -3.9297,  2.7872, -0.5834,  1.6945, -0.3919, -2.6519, -0.1661,
#         -2.0383, -3.7242])
# Logits for first image in batch: tensor([-0.1211, -4.5394, -0.2982, -0.2937,  1.3230,  0.0086, -2.4346,  2.9477,
#         -2.4811, -0.1499])
# Logits for first image in batch: tensor([ 5.7864, -0.8428,  2.4755, -2.1895, -0.8520, -3.4294, -1.0138, -5.5513,
#          1.6903, -3.1503])
# Logits for first image in batch: tensor([-2.2748, -1.8216, -0.5705,  0.3603, -2.6108,  1.2510, -2.3061,  1.8348,
#         -2.2482,  1.3974])
# Logits for first image in batch: tensor([-3.8228, -4.6755, -1.6461,  2.3888, -1.1099,  0.3758, -0.0319,  0.9677,
#          0.0931, -3.0767])
# Logits for first image in batch: tensor([-0.4281,  0.0343, -1.4479, -0.8334, -2.3748, -2.1888, -0.6432, -3.8281,
#          4.0303,  0.6336])
# Logits for first image in batch: tensor([ 1.8962,  3.1193, -3.1496, -2.5331, -2.3925, -4.5134, -3.2339, -4.1154,
#          3.0904,  5.6322])
# Logits for first image in batch: tensor([ 0.5200,  6.1282, -3.7015, -1.3769, -0.9674, -2.9811, -1.2359, -5.0715,
#          1.7403,  2.2149])
# Logits for first image in batch: tensor([ 2.4122,  1.2500, -2.4059, -2.7414, -1.8489, -3.4401, -3.5339, -0.8368,
#         -0.3712,  3.6572])
# Logits for first image in batch: tensor([ 3.6715, -2.7192,  0.1082, -1.4605, -1.0565, -3.1081, -1.6382, -3.5561,
#          3.5079, -3.2770])
# Logits for first image in batch: tensor([-1.6053, -3.3286,  1.0482,  1.8458,  1.5498,  1.9445,  0.9109, -0.4997,
#         -3.9693, -3.5250])
# Logits for first image in batch: tensor([-2.8638, -4.2828,  0.5472,  2.0197, -4.0384,  4.0146,  1.8020, -1.2811,
#         -1.7320, -2.6980])
# Logits for first image in batch: tensor([ 3.4989,  1.7320, -2.4446, -2.9881, -3.9172, -6.2604, -5.4021, -5.5626,
#          8.3814,  1.2527])
# Logits for first image in batch: tensor([-0.9645, -2.6753, -0.4828,  1.2470,  0.1020, -0.1527, -0.9141,  0.0705,
#         -1.6439, -1.2247])
# Logits for first image in batch: tensor([ 0.4202, -2.9006,  3.1423,  1.9913, -3.2890,  1.7688,  3.8651, -4.2107,
#         -5.4251, -2.2578])
# Logits for first image in batch: tensor([-2.7751, -5.0760,  0.7771,  1.7683,  1.6022,  0.9008,  0.9917,  0.3024,
#         -4.8751, -3.9229])
# Logits for first image in batch: tensor([ 0.7538,  3.6648, -2.9350, -2.8967, -2.8942, -3.7330, -1.1193, -1.3045,
#         -0.4680,  6.0709])
# Logits for first image in batch: tensor([ 1.0707, -0.6735, -1.3401,  0.9710, -1.1705,  0.1992, -3.0391, -1.2556,
#          2.9553, -1.4746])
# Logits for first image in batch: tensor([ 0.4634,  6.0176, -2.0090, -2.2200, -1.7089, -4.0264, -3.0749, -3.6458,
#          2.4839,  1.8117])
# Logits for first image in batch: tensor([ 3.9855,  1.1121, -0.3817, -1.5380, -1.6940, -4.8891, -3.0969, -6.3658,
#          6.5124, -0.4127])
# Logits for first image in batch: tensor([-0.3889, -0.8184,  1.9574,  1.0594, -1.9426,  0.4623,  0.0503, -0.7623,
#         -3.2105, -0.6969])
# Logits for first image in batch: tensor([-4.1471e+00, -2.1971e+00, -1.3264e+00, -5.9807e-01, -2.9680e-03,
#          1.6289e+00,  4.1285e+00,  7.1839e-01, -8.4130e+00,  3.7879e-01])
# Logits for first image in batch: tensor([ 2.1457,  2.5547, -3.3015, -4.3493, -2.3288, -6.2020, -4.4163, -3.8062,
#          5.2079,  3.7947])
# Logits for first image in batch: tensor([ 2.4046, -0.4796,  0.4955,  0.4783, -0.0494, -1.0111, -2.2437, -2.1907,
#          0.7604, -1.2066])
# Logits for first image in batch: tensor([ 5.1773, -2.2865,  1.5525, -0.6966,  0.3698, -2.0784, -4.0462, -2.7728,
#          1.8902, -4.6312])
# Logits for first image in batch: tensor([-2.9519, -5.4130,  0.3215,  2.1109, -0.9613, -0.0344,  1.6192, -0.5364,
#         -2.1608, -1.5710])
# Logits for first image in batch: tensor([-3.2412, -4.1087,  1.2201,  0.8436,  3.7138, -0.4093, -0.2483, -0.3019,
#         -3.2008, -4.0523])
# Logits for first image in batch: tensor([-1.0606, -1.2360,  0.2652,  0.0963, -0.2291,  0.1525, -1.9393,  0.8464,
#         -2.2043,  0.4439])
# Logits for first image in batch: tensor([ 4.5269,  1.8595, -0.1434, -2.3532, -1.8674, -4.5796, -2.7679, -3.9627,
#          2.5951,  2.4063])
# Logits for first image in batch: tensor([-2.4110, -2.7612,  0.8682,  1.7478, -0.0317,  1.4995,  1.5913, -2.2084,
#         -3.7968, -2.5797])
# Logits for first image in batch: tensor([-2.7318,  1.7618, -2.0444,  0.1737, -0.0880, -2.4664,  4.8601, -5.7300,
#         -1.3740, -0.2614])
# Logits for first image in batch: tensor([ 1.0911, -2.1254,  0.5350, -1.4517, -2.3628, -3.6099, -0.0242, -4.7400,
#          3.7600, -1.2175])
# Logits for first image in batch: tensor([ 0.2063, -1.1830,  0.1024,  1.3357,  1.0098, -0.8598, -2.5044, -2.4637,
#          0.4840, -0.3696])
# Logits for first image in batch: tensor([ 2.6482,  0.1698, -0.2028, -1.6090, -1.9243, -4.0155, -4.4611, -4.4453,
#          6.8064, -1.1457])
# Logits for first image in batch: tensor([ 3.5822,  0.3315,  1.2146, -0.3718, -0.6932, -1.7966, -5.1657, -2.3698,
#          3.0150, -2.8788])
# Logits for first image in batch: tensor([-0.2697, -4.2561,  3.1056,  0.9540,  0.4991,  0.5314, -1.2932, -0.6030,
#         -3.6889, -2.1444])
# Logits for first image in batch: tensor([-1.6913,  0.6722, -0.1280, -1.8681, -3.6504, -1.1681,  0.9777, -0.7406,
#         -1.4142,  4.3114])
# Logits for first image in batch: tensor([-0.0909, -1.4707,  0.0578, -0.9781, -1.0199, -0.2323, -2.8526,  1.9386,
#         -0.8621,  1.1586])
# Logits for first image in batch: tensor([ 1.1620, -4.0732,  0.3772, -0.7304,  1.8360, -1.0116,  3.6018, -0.9217,
#         -6.1691, -2.7035])
# Logits for first image in batch: tensor([-1.6946, -3.4860, -0.3351,  0.1567,  1.7574,  0.3648, -2.1219,  3.7164,
#         -3.3958, -2.5381])
# Surrogate Model Accuracy: 48.68%
